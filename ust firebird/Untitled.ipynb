# %%
from sage.all import *
import math

key=[..., ..., ..., ..., ..., ..., ..., ..., ..., ..., ..., ..., ..., ..., ..., ..., ...]

cipher=[..., ..., ..., ..., ..., ..., ..., ..., ..., ..., ..., ..., ..., ..., ..., ..., ...]

# for i in range(17):
#     for j in range(i+1,17):
#         if(math.gcd(key[i],key[j])!=1):
#             print(i,j)
#             # print(key[i])
#             # print(key[j])
#             print(math.gcd(key[i],key[j]))
# print(len(key))


CRT(cipher,key)
# print(())



# c =  [..., ..., ...]
# n =  [..., ..., ...]

# CRT(c,n)
# Out:
# ...

# %%
from Crypto.Util.number import bytes_to_long

import base64
from pwn import *
# from secret import flag





cipher = []
key = []

key.append(bytes_to_long(base64.b64decode("")))
cipher.append(...)
key.append(bytes_to_long(base64.b64decode("")))
cipher.append(...)

key.append(bytes_to_long(base64.b64decode("")))
cipher.append(...)

key.append(bytes_to_long(base64.b64decode("")))
cipher.append(...)
key.append(bytes_to_long(base64.b64decode("")))
cipher.append(...)

key.append(bytes_to_long(base64.b64decode("")))
cipher.append(...)

key.append(bytes_to_long(base64.b64decode("")))
cipher.append(...)

key.append(bytes_to_long(base64.b64decode("")))
cipher.append(...)


key.append(bytes_to_long(base64.b64decode("")))
cipher.append(...)

key.append(bytes_to_long(base64.b64decode("")))
cipher.append(...)

key.append(bytes_to_long(base64.b64decode("")))
cipher.append(...)

key.append(bytes_to_long(base64.b64decode("")))
cipher.append(...)

key.append(bytes_to_long(base64.b64decode("")))
cipher.append(...)


key.append(bytes_to_long(base64.b64decode("")))
cipher.append(...)


key.append(bytes_to_long(base64.b64decode("")))
cipher.append(...)

key.append(bytes_to_long(base64.b64decode("")))
cipher.append(...)

key.append(bytes_to_long(base64.b64decode("")))
cipher.append(...)

print(len(key))
print(len(cipher))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [13], line 1
# ----> 1 from Crypto.Util.number import bytes_to_long
#       3 import base64
#       4 from pwn import *
#
# ModuleNotFoundError: No module named 'Crypto'
